# %%
import pandas as pd
import numpy as np

# %%
df_Riss_research = pd.read_csv("./csv/Seleniums.academic_research.csv")
df_Riss_research[:10]
df_Riss_research.drop
# Out:
#                         _id  \
# 0  65e6f0cd7436f20b02adf073
# 1  65e6f0d17436f20b02adf074
# 2  65e6f0d47436f20b02adf075
# 3  65e6f0d87436f20b02adf076
# 4  65e6f0dc7436f20b02adf077
# 5  65e6f0df7436f20b02adf078
# 6  65e6f0e37436f20b02adf079
# 7  65e6f0e77436f20b02adf07a
# 8  65e6f0ea7436f20b02adf07b
# 9  65e6f0ee7436f20b02adf07c
#
#                                       research_title  \
# 0  희귀 선천성 유전질환의 진단법 개발 및 진단기준 마련  :  신생아 선천성 대사이상...
# 1  국내 희귀의약품의 현황 및 과제  :  희귀질환에 대한 의약품 공급을 중심으로 = ...
# 2                        「희귀질환관리법」상 의료비 지원 사업에 관한 소고
# 3                  희귀난치질환아를 키우는 부모의 셰어런팅 현황과 양육지원 요구
# 4  희귀난치성질환 장애인의 주관적 건강상태 영향요인에 대한 탐색적 연구 = An exp...
# 5  희귀난치성질환자 지원사업의 정책분석과 개선방안 연구  :  전라북도에서의 정책집행 ...
# 6  미국의 희귀질환에 대한 의료 지원 정책 = Medical Support Polici...
# 7  희귀질환 연구와 치료제 개발 동향 = Rare Disease Research and...
# 8  희귀질환을 가지고 있는 장애학생의 질환별 특성 및 교육적 지원 고찰 = A Stud...
# 9  희귀질환을 가진 중증장애학생의 교육적 고려 실태 및 지원방안 = The Practi...
#
#                              research_url  \
# ...
