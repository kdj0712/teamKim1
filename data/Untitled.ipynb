# %%
import pandas as pd

# %%
df_eng = pd.read_csv("./csv/Seleniums.eng_academic_research.csv")
df_eng[:2]
# Out:
#                         _id  \
# 0  65e9597040f212b5a12eed8e
# 1  65e9597440f212b5a12eed8f
#
#                                       research_title  \
# 0  Collaboration through the Asia Pacific MPS Net...
# 1  Journal of Mucopolysaccharidosis and Rare Dise...
#
#                              research_url research_author  \
# 0  https://www.riss.kr/link?id=A102412091  Cho, Sung Yoon
# 1  https://www.riss.kr/link?id=A102412090   Jin, Dong-Kyu
#
#                                 research_institution  \
# 0  Association for Research of MPS and Rare Diseases
# 1  Association for Research of MPS and Rare Diseases
#
#                                        research_name    research_volumn  \
# 0  Journal of mucopolysaccharidosis and rare disease  Vol.1 No.1 [2015]
# 1  Journal of mucopolysaccharidosis and rare disease  Vol.1 No.1 [2015]
#
#    research_year research_language  \
# 0           2015           English
# 1           2015           English
#
# ...

# %%
df_eng.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15585 entries, 0 to 15584
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   _id                   15585 non-null  object
#  1   research_title        15585 non-null  object
#  2   research_url          15585 non-null  object
#  3   research_author       15585 non-null  object
#  4   research_institution  15585 non-null  object
#  5   research_name         15584 non-null  object
#  6   research_volumn       15585 non-null  object
#  7   research_year         15585 non-null  int64
#  8   research_language     15585 non-null  object
#  9   research_subject      15585 non-null  object
#  10  research_type         15584 non-null  object
#  11  research_page         15585 non-null  object
# dtypes: int64(1), object(11)
# memory usage: 1.4+ MB

# %%
df_kor = pd.read_csv("./csv/Seleniums.academic_research.csv")
df_kor[:2]
# Out:
#                         _id  \
# 0  65e6f0cd7436f20b02adf073
# 1  65e6f0d17436f20b02adf074
#
#                                       research_title  \
# 0  희귀 선천성 유전질환의 진단법 개발 및 진단기준 마련  :  신생아 선천성 대사이상...
# 1  국내 희귀의약품의 현황 및 과제  :  희귀질환에 대한 의약품 공급을 중심으로 = ...
#
#                             research_url  \
# 0  https://www.riss.kr/link?id=A18683251
# 1  https://www.riss.kr/link?id=A75064621
#
#                                      research_author research_institution  \
# 0  김성수 (국립보건원 특수질환부 유전질환과) ;  이환석 (국립보건원 특수질환부 유전...              국립보건연구원
# 1  김희은 (이화여자대학교 임상보건과학대학원) ;  곽혜선 (이화여자대학교 임상보건과학...        이화여자대학교 약학연구소
#
#                                        research_name     research_volumn  \
# 0  국립보건원보(The Report of National Institute of Hea...  Vol.37 No.- [2000]
# 1                                            藥學硏究論文集  Vol.- No.17 [2008]
#
#    research_year research_language  \
# 0           2000            Korean
# 1           2008            Korean
#
# ...

# %%
df_kor.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 351 entries, 0 to 350
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   _id                   351 non-null    object
#  1   research_title        351 non-null    object
#  2   research_url          351 non-null    object
#  3   research_author       351 non-null    object
#  4   research_institution  351 non-null    object
#  5   research_name         351 non-null    object
#  6   research_volumn       351 non-null    object
#  7   research_year         351 non-null    int64
#  8   research_language     351 non-null    object
#  9   research_subject      348 non-null    object
#  10  research_type         350 non-null    object
#  11  research_page         351 non-null    object
# dtypes: int64(1), object(11)
# memory usage: 33.0+ KB
